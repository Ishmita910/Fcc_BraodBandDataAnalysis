# %%
import pandas as pd
import csv

df= pd.read_csv("Average_download_upload_speeds_by_State.csv",index_col = None)

# %%
df.head()
# Out:
#   State  Max Advertised Downstream Speed (mbps)  \
# 0    AK                               68.417806
# 1    AL                               46.526628
# 2    AR                               32.092688
# 3    AS                                4.916436
# 4    AZ                               36.070985
#
#    Max Advertised Upstream Speed (mbps)  Max CIR Downstream Speed (mbps)  \
# 0                              5.168614                        12.643135
# 1                             11.644438                         8.364268
# 2                              7.024608                        14.187174
# 3                              4.912000                         4.930705
# 4                              8.500237                        55.629490
#
#    Max CIR Upstream Speed (mbps)
# 0                       9.026021
# 1                       5.890953
# 2                       8.295491
# 3                       4.924188
# 4                      45.531177

# %%
df.plot

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df[['State','Max Advertised Downstream Speed (mbps)','Max Advertised Upstream Speed (mbps)']].plot.bar( x='State', figsize=(20,10))

# %%
import geopandas as gpd
cellular = gpd.GeoDataFrame.from_file("Cellular_Service_Areas.shp")

# %%
cellular.plot()

# %%
>>> sg_boundary = cellular.ix[1].geometry

>>> sg_boundary
# Out:
# C:\Users\Ishmita\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
cellular.geometry
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-764136abe843> in <module>()
# ----> 1 cellular.geometry.value
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'GeoSeries' object has no attribute 'value'

# %%
# mean wrt weekDay rtt Average
